# %%
import pandas as pd

scores = [
    {'chinese':78,'english':80,'math':92,'history':75,'discover':85},
    {'chinese':92,'english':60,'math':85,'history':62,'discover':73}
]
dataFrame = pd.DataFrame(index=["robert","jenny"],data=scores)
display(dataFrame.T)
# Out:
#           robert  jenny
# chinese       78     92
# english       80     60
# math          92     85
# history       75     62
# discover      85     73

# %%
import matplotlib.pyplot as plt
figure = plt.figure()
axes = figure.add_subplot(1,1,1)
dataFrame.T.plot(ax=axes)
axes.set_title('Scores')
axes.grid(visible=True,axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
figure = plt.figure()
axes = figure.add_subplot(1,1,1)
dataFrame.T.plot(ax=axes,style=['--','-'])
axes.set_title('Scores')
axes.grid(visible=True,axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
figure = plt.figure()
axes = figure.add_subplot(1,1,1)
dataFrame.T.plot(ax=axes,style=['--','-'],marker='o')
axes.set_title('Scores')
axes.grid(visible=True,axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
#windos
font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)
#mac
#font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)
#codespace
#font=FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)

figure = plt.figure()
axes = figure.add_subplot(1,1,1)
dataFrame.T.plot(ax=axes,style=['--','-'],marker='o')
axes.set_title('徐國堂和徐家家分數比較表',fontproperties=font)
axes.grid(visible=True,axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
#windows
font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)
#mac
#font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)
#codespace
#font=FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)

figure = plt.figure()
axes = figure.add_subplot(1,1,1)
dataFrame.T.plot(ax=axes,style=['--','-'],marker='o')
axes.set_title('徐國堂和徐家家分數比較表',fontproperties=font)

#legend = axes.get_legend()
#legend.fontproperties = font
axes.grid(visible=True,axis='y')
plt.show()
